# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries

import pandas as pd
import numpy as np
from citipy import citipy
from scipy import stats

# %%
# adding everything from module
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
import requests

# %%
# adding everything from module
# Import the datetime module from the datetime library.
from datetime import datetime

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ff5cdb64b943b70f68c31e2c3da5caa3

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 1 | novoseleznevo
# Processing Record 3 of Set 1 | dalby
# Processing Record 4 of Set 1 | pagsangahan
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | guerrero negro
# Processing Record 7 of Set 1 | kautokeino
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | dubrovnik
# Processing Record 18 of Set 1 | barstow
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | quelimane
# Processing Record 25 of Set 1 | tuatapere
# Processing Record 26 of Set 1 | launceston
# Processing Record 27 of Set 1 | sokone
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | koumac
# Processing Record 32 of Set 1 | wanxian
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | nanortalik
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | ixtapa
# Processing Record 37 of Set 1 | dzhebariki-khaya
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | manado
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | cabedelo
# Processing Record 43 of Set 1 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 44 of Set 1 | inongo
# Processing Record 45 of Set 1 | lieksa
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | mezen
# Processing Record 49 of Set 1 | yumen
# Processing Record 50 of Set 1 | yurla
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | bogovarovo
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | gamboula
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | conakry
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 2 | moree
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | sobolevo
# Processing Record 17 of Set 2 | vao
# Processing Record 18 of Set 2 | acapulco
# Processing Record 19 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 2 | grindavik
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | shache
# Processing Record 25 of Set 2 | saraland
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | takayama
# Processing Record 28 of Set 2 | auki
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | aksum
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | tancheng
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | brae
# Processing Record 36 of Set 2 | samarai
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | port macquarie
# Processing Record 40 of Set 2 | tateyama
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | yinchuan
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | villingen-schwenningen
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | wilkie
# Processing Record 49 of Set 2 | arman
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 3 | evensk
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | carauari
# Processing Record 6 of Set 3 | vestmannaeyjar
# Processing Record 7 of Set 3 | arcachon
# Processing Record 8 of Set 3 | lagoa
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | chino valley
# Processing Record 14 of Set 3 | jaru
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | chumikan
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | buraydah
# Processing Record 19 of Set 3 | havre-saint-pierre
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | sao felix do xingu
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | kruszwica
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | touros
# Processing Record 26 of Set 3 | jiuquan
# Processing Record 27 of Set 3 | santa catarina palopo
# Processing Record 28 of Set 3 | taganak
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | tiksi
# Processing Record 31 of Set 3 | port lincoln
# Processing Record 32 of Set 3 | igrim
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | dambulla
# Processing Record 36 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | namatanai
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | puerto colombia
# Processing Record 40 of Set 3 | khandyga
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | primorsko
# Processing Record 43 of Set 3 | lucapa
# Processing Record 44 of Set 3 | javanrud
# Processing Record 45 of Set 3 | nara
# Processing Record 46 of Set 3 | birin
# Processing Record 47 of Set 3 | fredericksburg
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | mersing
# Processing Record 50 of Set 3 | hilo
# Processing Record 1 of Set 4 | yar-sale
# Processing Record 2 of Set 4 | sri aman
# Processing Record 3 of Set 4 | barentu
# Processing Record 4 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 4 | espinosa
# Processing Record 6 of Set 4 | iraquara
# Processing Record 7 of Set 4 | jibuti
# Processing Record 8 of Set 4 | bhanpuri
# Processing Record 9 of Set 4 | talcahuano
# Processing Record 10 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 4 | pavlodar
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | catamarca
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | hobyo
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | luau
# Processing Record 18 of Set 4 | fort nelson
# Processing Record 19 of Set 4 | livingston
# Processing Record 20 of Set 4 | boende
# Processing Record 21 of Set 4 | barranca
# Processing Record 22 of Set 4 | berezovyy
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | pangody
# Processing Record 25 of Set 4 | kiruna
# Processing Record 26 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 27 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 4 | ust-tsilma
# Processing Record 29 of Set 4 | juba
# Processing Record 30 of Set 4 | port alfred
# Processing Record 31 of Set 4 | baker city
# Processing Record 32 of Set 4 | mendi
# Processing Record 33 of Set 4 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 4 | goalpara
# Processing Record 35 of Set 4 | jinchang
# Processing Record 36 of Set 4 | sorland
# Processing Record 37 of Set 4 | clarence town
# Processing Record 38 of Set 4 | leh
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | dawson creek
# Processing Record 41 of Set 4 | praia
# Processing Record 42 of Set 4 | carutapera
# Processing Record 43 of Set 4 | seymour
# Processing Record 44 of Set 4 | walvis bay
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | araruna
# Processing Record 47 of Set 4 | marquette
# Processing Record 48 of Set 4 | dingle
# Processing Record 49 of Set 4 | fengzhen
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | kemijarvi
# Processing Record 2 of Set 5 | porto novo
# Processing Record 3 of Set 5 | haiger
# Processing Record 4 of Set 5 | waipawa
# Processing Record 5 of Set 5 | havoysund
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | swan river
# Processing Record 8 of Set 5 | tanah merah
# Processing Record 9 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 5 | shieli
# Processing Record 11 of Set 5 | port blair
# Processing Record 12 of Set 5 | baruun-urt
# Processing Record 13 of Set 5 | ukwa
# Processing Record 14 of Set 5 | limbang
# Processing Record 15 of Set 5 | sao joao da barra
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | mao
# Processing Record 18 of Set 5 | naze
# Processing Record 19 of Set 5 | save
# Processing Record 20 of Set 5 | suntar
# Processing Record 21 of Set 5 | fort-shevchenko
# Processing Record 22 of Set 5 | kuva
# City not found. Skipping...
# Processing Record 23 of Set 5 | nabire
# Processing Record 24 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | usinsk
# Processing Record 27 of Set 5 | bredasdorp
# Processing Record 28 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 5 | cape town
# Processing Record 30 of Set 5 | treinta y tres
# Processing Record 31 of Set 5 | hami
# Processing Record 32 of Set 5 | banff
# Processing Record 33 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 34 of Set 5 | goure
# Processing Record 35 of Set 5 | nova vicosa
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | griffith
# Processing Record 38 of Set 5 | souillac
# Processing Record 39 of Set 5 | kushiro
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | bengkulu
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | freeport
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 5 | pangai
# Processing Record 48 of Set 5 | fuyang
# Processing Record 49 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 5 | westport
# Processing Record 1 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 6 | bogale
# Processing Record 3 of Set 6 | broken hill
# Processing Record 4 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | klaksvik
# Processing Record 7 of Set 6 | malinovskiy
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | ulaangom
# Processing Record 10 of Set 6 | codajas
# Processing Record 11 of Set 6 | chachapoyas
# Processing Record 12 of Set 6 | bossangoa
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | nanning
# Processing Record 15 of Set 6 | camapua
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | zhigansk
# Processing Record 18 of Set 6 | cartagena
# Processing Record 19 of Set 6 | golden
# Processing Record 20 of Set 6 | juan lacaze
# Processing Record 21 of Set 6 | kaeo
# Processing Record 22 of Set 6 | bandundu
# Processing Record 23 of Set 6 | jiangyou
# Processing Record 24 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 6 | ariquemes
# Processing Record 26 of Set 6 | port shepstone
# Processing Record 27 of Set 6 | caravelas
# Processing Record 28 of Set 6 | mae sai
# Processing Record 29 of Set 6 | central point
# Processing Record 30 of Set 6 | panzhihua
# Processing Record 31 of Set 6 | umm lajj
# Processing Record 32 of Set 6 | kaniama
# Processing Record 33 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 6 | bronnoysund
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | rundu
# Processing Record 37 of Set 6 | kurilsk
# Processing Record 38 of Set 6 | tuktoyaktuk
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | clyde river
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | aswan
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | lubben
# Processing Record 45 of Set 6 | pascagoula
# Processing Record 46 of Set 6 | taoudenni
# Processing Record 47 of Set 6 | pemberton
# Processing Record 48 of Set 6 | juneau
# Processing Record 49 of Set 6 | korla
# Processing Record 50 of Set 6 | marsh harbour
# Processing Record 1 of Set 7 | ancud
# Processing Record 2 of Set 7 | charters towers
# Processing Record 3 of Set 7 | atambua
# Processing Record 4 of Set 7 | ashland
# Processing Record 5 of Set 7 | presidencia roque saenz pena
# Processing Record 6 of Set 7 | bonham
# Processing Record 7 of Set 7 | tymovskoye
# Processing Record 8 of Set 7 | kruisfontein
# Processing Record 9 of Set 7 | saskylakh
# Processing Record 10 of Set 7 | sinnamary
# Processing Record 11 of Set 7 | port augusta
# Processing Record 12 of Set 7 | hovd
# Processing Record 13 of Set 7 | obo
# Processing Record 14 of Set 7 | kidal
# Processing Record 15 of Set 7 | hazorasp
# Processing Record 16 of Set 7 | teknaf
# Processing Record 17 of Set 7 | linfen
# Processing Record 18 of Set 7 | humaita
# Processing Record 19 of Set 7 | gimli
# Processing Record 20 of Set 7 | ulladulla
# Processing Record 21 of Set 7 | santa isabel do rio negro
# Processing Record 22 of Set 7 | chipata
# Processing Record 23 of Set 7 | saint anthony
# Processing Record 24 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 7 | himora
# City not found. Skipping...
# Processing Record 26 of Set 7 | semey
# Processing Record 27 of Set 7 | sauda
# Processing Record 28 of Set 7 | broome
# Processing Record 29 of Set 7 | wloclawek
# Processing Record 30 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 7 | filadelfia
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | neiafu
# Processing Record 34 of Set 7 | ati
# Processing Record 35 of Set 7 | olafsvik
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | jalu
# Processing Record 38 of Set 7 | batangafo
# Processing Record 39 of Set 7 | law
# Processing Record 40 of Set 7 | rozhyshche
# Processing Record 41 of Set 7 | bull savanna
# Processing Record 42 of Set 7 | laguna
# Processing Record 43 of Set 7 | balkanabat
# Processing Record 44 of Set 7 | egvekinot
# Processing Record 45 of Set 7 | aasiaat
# Processing Record 46 of Set 7 | manokwari
# Processing Record 47 of Set 7 | gat
# Processing Record 48 of Set 7 | presidente olegario
# Processing Record 49 of Set 7 | alindao
# Processing Record 50 of Set 7 | natal
# Processing Record 1 of Set 8 | costa rica
# Processing Record 2 of Set 8 | bud
# Processing Record 3 of Set 8 | kuteynykove
# Processing Record 4 of Set 8 | lamu
# Processing Record 5 of Set 8 | bakel
# Processing Record 6 of Set 8 | tupancireta
# Processing Record 7 of Set 8 | tiznit
# Processing Record 8 of Set 8 | sumenep
# Processing Record 9 of Set 8 | ekibastuz
# Processing Record 10 of Set 8 | antofagasta
# Processing Record 11 of Set 8 | revda
# Processing Record 12 of Set 8 | makow mazowiecki
# Processing Record 13 of Set 8 | awbari
# Processing Record 14 of Set 8 | aripuana
# Processing Record 15 of Set 8 | bilhaur
# Processing Record 16 of Set 8 | sechura
# Processing Record 17 of Set 8 | sitka
# Processing Record 18 of Set 8 | rawson
# Processing Record 19 of Set 8 | mar del plata
# Processing Record 20 of Set 8 | vostok
# Processing Record 21 of Set 8 | cairns
# Processing Record 22 of Set 8 | coihaique
# Processing Record 23 of Set 8 | ugoofaaru
# Processing Record 24 of Set 8 | caxito
# Processing Record 25 of Set 8 | mangan
# Processing Record 26 of Set 8 | kamsack
# Processing Record 27 of Set 8 | mattru
# Processing Record 28 of Set 8 | xining
# Processing Record 29 of Set 8 | bandarbeyla
# Processing Record 30 of Set 8 | iskateley
# Processing Record 31 of Set 8 | bimbo
# Processing Record 32 of Set 8 | estevan
# Processing Record 33 of Set 8 | sioux lookout
# Processing Record 34 of Set 8 | najran
# Processing Record 35 of Set 8 | manta
# Processing Record 36 of Set 8 | college
# Processing Record 37 of Set 8 | matara
# Processing Record 38 of Set 8 | marystown
# Processing Record 39 of Set 8 | wigston
# Processing Record 40 of Set 8 | luderitz
# Processing Record 41 of Set 8 | hay river
# Processing Record 42 of Set 8 | ojuelos de jalisco
# Processing Record 43 of Set 8 | fairbanks
# Processing Record 44 of Set 8 | gigmoto
# Processing Record 45 of Set 8 | asfi
# Processing Record 46 of Set 8 | deputatskiy
# Processing Record 47 of Set 8 | berezna
# Processing Record 48 of Set 8 | terrace
# Processing Record 49 of Set 8 | aljezur
# Processing Record 50 of Set 8 | asau
# Processing Record 1 of Set 9 | la palma
# Processing Record 2 of Set 9 | manuk mangkaw
# Processing Record 3 of Set 9 | elizabeth city
# Processing Record 4 of Set 9 | belmonte
# Processing Record 5 of Set 9 | diapaga
# Processing Record 6 of Set 9 | maragogi
# Processing Record 7 of Set 9 | tazovskiy
# Processing Record 8 of Set 9 | stromness
# Processing Record 9 of Set 9 | manbij
# Processing Record 10 of Set 9 | pochutla
# Processing Record 11 of Set 9 | marsa matruh
# Processing Record 12 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 9 | galveston
# Processing Record 14 of Set 9 | saurimo
# Processing Record 15 of Set 9 | lagunas
# Processing Record 16 of Set 9 | saint-leu
# Processing Record 17 of Set 9 | isla vista
# Processing Record 18 of Set 9 | alyangula
# Processing Record 19 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 9 | constitucion
# Processing Record 21 of Set 9 | voyinka
# Processing Record 22 of Set 9 | sabang
# Processing Record 23 of Set 9 | mananjary
# Processing Record 24 of Set 9 | lewistown
# Processing Record 25 of Set 9 | chimbote
# Processing Record 26 of Set 9 | baghdad
# Processing Record 27 of Set 9 | san cristobal
# Processing Record 28 of Set 9 | grimshaw
# Processing Record 29 of Set 9 | vineland
# Processing Record 30 of Set 9 | progreso
# Processing Record 31 of Set 9 | cassilandia
# Processing Record 32 of Set 9 | mount gambier
# Processing Record 33 of Set 9 | tocopilla
# Processing Record 34 of Set 9 | llanes
# Processing Record 35 of Set 9 | thinadhoo
# Processing Record 36 of Set 9 | yichang
# Processing Record 37 of Set 9 | berdigestyakh
# Processing Record 38 of Set 9 | katherine
# Processing Record 39 of Set 9 | arica
# Processing Record 40 of Set 9 | whakatane
# Processing Record 41 of Set 9 | harrisonburg
# Processing Record 42 of Set 9 | anadyr
# Processing Record 43 of Set 9 | anchorage
# Processing Record 44 of Set 9 | xudat
# Processing Record 45 of Set 9 | poum
# Processing Record 46 of Set 9 | aldan
# Processing Record 47 of Set 9 | phalaborwa
# Processing Record 48 of Set 9 | saint-pierre
# Processing Record 49 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 9 | tautira
# Processing Record 1 of Set 10 | bahawalnagar
# Processing Record 2 of Set 10 | comodoro rivadavia
# Processing Record 3 of Set 10 | flinders
# Processing Record 4 of Set 10 | rio gallegos
# Processing Record 5 of Set 10 | viramgam
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | kavaratti
# Processing Record 8 of Set 10 | zyryanka
# Processing Record 9 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 10 | general cepeda
# Processing Record 11 of Set 10 | ahipara
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | juybar
# Processing Record 14 of Set 10 | sept-iles
# Processing Record 15 of Set 10 | cherskiy
# Processing Record 16 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | yerbogachen
# Processing Record 19 of Set 10 | emba
# Processing Record 20 of Set 10 | seoni malwa
# Processing Record 21 of Set 10 | edd
# Processing Record 22 of Set 10 | krasnopillya
# Processing Record 23 of Set 10 | portland
# Processing Record 24 of Set 10 | saldanha
# Processing Record 25 of Set 10 | say
# Processing Record 26 of Set 10 | talnakh
# Processing Record 27 of Set 10 | conceicao do araguaia
# Processing Record 28 of Set 10 | grudziadz
# Processing Record 29 of Set 10 | prince rupert
# Processing Record 30 of Set 10 | kovdor
# Processing Record 31 of Set 10 | eydhafushi
# Processing Record 32 of Set 10 | orlik
# Processing Record 33 of Set 10 | husavik
# Processing Record 34 of Set 10 | severnoye
# Processing Record 35 of Set 10 | grandview
# Processing Record 36 of Set 10 | aras
# Processing Record 37 of Set 10 | nelson bay
# Processing Record 38 of Set 10 | fez
# Processing Record 39 of Set 10 | saint-augustin
# Processing Record 40 of Set 10 | syamzha
# Processing Record 41 of Set 10 | pangnirtung
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | kavieng
# Processing Record 44 of Set 10 | jaguaquara
# Processing Record 45 of Set 10 | maniitsoq
# Processing Record 46 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 10 | pacific grove
# Processing Record 48 of Set 10 | nuuk
# Processing Record 49 of Set 10 | nadadores
# Processing Record 50 of Set 10 | baracoa
# Processing Record 1 of Set 11 | athabasca
# Processing Record 2 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 11 | aksu
# Processing Record 4 of Set 11 | bijar
# Processing Record 5 of Set 11 | ngama
# Processing Record 6 of Set 11 | inhambane
# Processing Record 7 of Set 11 | pires do rio
# Processing Record 8 of Set 11 | mount juliet
# Processing Record 9 of Set 11 | toora-khem
# Processing Record 10 of Set 11 | sambava
# Processing Record 11 of Set 11 | wad madani
# Processing Record 12 of Set 11 | marzuq
# Processing Record 13 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 11 | ayan
# Processing Record 15 of Set 11 | joshimath
# Processing Record 16 of Set 11 | hammerfest
# Processing Record 17 of Set 11 | labuhan
# Processing Record 18 of Set 11 | atar
# Processing Record 19 of Set 11 | lyuban
# Processing Record 20 of Set 11 | west bay
# Processing Record 21 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 22 of Set 11 | sibu
# Processing Record 23 of Set 11 | tual
# Processing Record 24 of Set 11 | alpena
# Processing Record 25 of Set 11 | padang
# Processing Record 26 of Set 11 | ventspils
# Processing Record 27 of Set 11 | voh
# Processing Record 28 of Set 11 | umm kaddadah
# Processing Record 29 of Set 11 | ous
# Processing Record 30 of Set 11 | wukari
# Processing Record 31 of Set 11 | pemangkat
# Processing Record 32 of Set 11 | jhang
# Processing Record 33 of Set 11 | rongcheng
# Processing Record 34 of Set 11 | awjilah
# Processing Record 35 of Set 11 | santa barbara
# Processing Record 36 of Set 11 | kamenka
# Processing Record 37 of Set 11 | andra
# Processing Record 38 of Set 11 | ak-dovurak
# Processing Record 39 of Set 11 | zhanjiang
# Processing Record 40 of Set 11 | la crosse
# Processing Record 41 of Set 11 | angoche
# Processing Record 42 of Set 11 | tukrah
# Processing Record 43 of Set 11 | itaituba
# Processing Record 44 of Set 11 | kaoma
# Processing Record 45 of Set 11 | beira
# Processing Record 46 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 11 | ucluelet
# Processing Record 48 of Set 11 | verkhoyansk
# Processing Record 49 of Set 11 | pontianak
# Processing Record 50 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 12 | onega
# Processing Record 2 of Set 12 | ivanovka
# Processing Record 3 of Set 12 | lompoc
# Processing Record 4 of Set 12 | oriximina
# Processing Record 5 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 12 | newark
# Processing Record 7 of Set 12 | hoquiam
# Processing Record 8 of Set 12 | krasnyy oktyabr
# Processing Record 9 of Set 12 | makakilo city
# Processing Record 10 of Set 12 | basoko
# Processing Record 11 of Set 12 | chirongui
# Processing Record 12 of Set 12 | brive-la-gaillarde
# Processing Record 13 of Set 12 | alto vera
# City not found. Skipping...
# Processing Record 14 of Set 12 | toktogul
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | payo
# Processing Record 17 of Set 12 | kerema
# Processing Record 18 of Set 12 | omboue
# Processing Record 19 of Set 12 | saint-louis
# Processing Record 20 of Set 12 | kondratovo
# Processing Record 21 of Set 12 | brasilia
# Processing Record 22 of Set 12 | agirish
# Processing Record 23 of Set 12 | pontian kecil
# Processing Record 24 of Set 12 | salina cruz
# Processing Record 25 of Set 12 | inverell
# Processing Record 26 of Set 12 | martapura
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | palm coast
# Processing Record 29 of Set 12 | cayenne
# Processing Record 30 of Set 12 | sur
# Processing Record 31 of Set 12 | qaqortoq
# Processing Record 32 of Set 12 | granada
# Processing Record 33 of Set 12 | barda
# Processing Record 34 of Set 12 | ola
# Processing Record 35 of Set 12 | borinskoye
# Processing Record 36 of Set 12 | grand gaube
# Processing Record 37 of Set 12 | beliator
# Processing Record 38 of Set 12 | novovarshavka
# Processing Record 39 of Set 12 | baoro
# Processing Record 40 of Set 12 | rodez
# Processing Record 41 of Set 12 | conde
# Processing Record 42 of Set 12 | san fernando
# Processing Record 43 of Set 12 | mareeba
# Processing Record 44 of Set 12 | teul
# City not found. Skipping...
# Processing Record 45 of Set 12 | colwyn bay
# Processing Record 46 of Set 12 | puerto maldonado
# Processing Record 47 of Set 12 | malakal
# Processing Record 48 of Set 12 | saint george
# Processing Record 49 of Set 12 | trincomalee
# Processing Record 50 of Set 12 | isla mujeres
# Processing Record 1 of Set 13 | canon city
# Processing Record 2 of Set 13 | carora
# Processing Record 3 of Set 13 | kieta
# Processing Record 4 of Set 13 | sabla
# Processing Record 5 of Set 13 | arrifes
# Processing Record 6 of Set 13 | hibbing
# Processing Record 7 of Set 13 | port hedland
# Processing Record 8 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 13 | yarim
# Processing Record 10 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 13 | vikhorevka
# Processing Record 12 of Set 13 | nome
# Processing Record 13 of Set 13 | havelock
# Processing Record 14 of Set 13 | algiers
# Processing Record 15 of Set 13 | luganville
# Processing Record 16 of Set 13 | avera
# Processing Record 17 of Set 13 | liaocheng
# Processing Record 18 of Set 13 | palana
# Processing Record 19 of Set 13 | tezu
# Processing Record 20 of Set 13 | kapuskasing
# Processing Record 21 of Set 13 | kangaatsiaq
# Processing Record 22 of Set 13 | etchoropo
# Processing Record 23 of Set 13 | surajgarh
# Processing Record 24 of Set 13 | saqqez
# Processing Record 25 of Set 13 | huarmey
# Processing Record 26 of Set 13 | cap malheureux
# Processing Record 27 of Set 13 | bar harbor
# Processing Record 28 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 13 | lethem
# Processing Record 30 of Set 13 | chamba
# Processing Record 31 of Set 13 | herat
# Processing Record 32 of Set 13 | nouakchott
# Processing Record 33 of Set 13 | chapada dos guimaraes
# Processing Record 34 of Set 13 | nizhnevartovsk
# Processing Record 35 of Set 13 | hasaki
# Processing Record 36 of Set 13 | vytegra
# Processing Record 37 of Set 13 | brejo santo
# Processing Record 38 of Set 13 | moose factory
# Processing Record 39 of Set 13 | watsa
# Processing Record 40 of Set 13 | peniche
# Processing Record 41 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 13 | opalikha
# Processing Record 43 of Set 13 | katobu
# Processing Record 44 of Set 13 | bathsheba
# Processing Record 45 of Set 13 | sheremetyevskiy
# Processing Record 46 of Set 13 | dillon
# Processing Record 47 of Set 13 | luena
# Processing Record 48 of Set 13 | bodo
# Processing Record 49 of Set 13 | houma
# Processing Record 50 of Set 13 | ulsteinvik
# Processing Record 1 of Set 14 | yubileynyy
# Processing Record 2 of Set 14 | nouadhibou
# Processing Record 3 of Set 14 | pucallpa
# Processing Record 4 of Set 14 | palmas
# Processing Record 5 of Set 14 | mabaruma
# Processing Record 6 of Set 14 | sahuaripa
# Processing Record 7 of Set 14 | nandu
# Processing Record 8 of Set 14 | dera bugti
# Processing Record 9 of Set 14 | clearwater
# Processing Record 10 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 14 | svetlogorsk
# Processing Record 12 of Set 14 | camacha
# Processing Record 13 of Set 14 | marienburg
# Processing Record 14 of Set 14 | brigantine
# Processing Record 15 of Set 14 | ballitoville
# Processing Record 16 of Set 14 | sierra vista
# Processing Record 17 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 14 | salinopolis
# Processing Record 19 of Set 14 | ler
# Processing Record 20 of Set 14 | bara
# Processing Record 21 of Set 14 | rudnyy
# Processing Record 22 of Set 14 | el tigre
# Processing Record 23 of Set 14 | komsomolskiy
# Processing Record 24 of Set 14 | vardo
# Processing Record 25 of Set 14 | miles city
# Processing Record 26 of Set 14 | pyaozerskiy
# Processing Record 27 of Set 14 | kanigiri
# Processing Record 28 of Set 14 | dinguiraye
# Processing Record 29 of Set 14 | linares
# Processing Record 30 of Set 14 | itarema
# Processing Record 31 of Set 14 | nioro
# Processing Record 32 of Set 14 | bhag
# Processing Record 33 of Set 14 | ayni
# Processing Record 34 of Set 14 | vakhrushev
# Processing Record 35 of Set 14 | udachnyy
# Processing Record 36 of Set 14 | san rafael
# Processing Record 37 of Set 14 | homer
# Processing Record 38 of Set 14 | yaan
# Processing Record 39 of Set 14 | port-cartier
# Processing Record 40 of Set 14 | placido de castro
# Processing Record 41 of Set 14 | oranjestad
# Processing Record 42 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 14 | cockburn town
# Processing Record 44 of Set 14 | zhovtneve
# Processing Record 45 of Set 14 | nyurba
# Processing Record 46 of Set 14 | los llanos de aridane
# Processing Record 47 of Set 14 | vanavara
# Processing Record 48 of Set 14 | niles
# Processing Record 49 of Set 14 | palmer
# Processing Record 50 of Set 14 | valparaiso
# Processing Record 1 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 2 of Set 15 | te anau
# Processing Record 3 of Set 15 | lubawa
# Processing Record 4 of Set 15 | alice springs
# Processing Record 5 of Set 15 | teguldet
# Processing Record 6 of Set 15 | beringovskiy
# Processing Record 7 of Set 15 | ilo
# Processing Record 8 of Set 15 | tacadang
# Processing Record 9 of Set 15 | florianopolis
# Processing Record 10 of Set 15 | bitam
# Processing Record 11 of Set 15 | iberia
# Processing Record 12 of Set 15 | adrar
# Processing Record 13 of Set 15 | jumla
# Processing Record 14 of Set 15 | esmeralda
# Processing Record 15 of Set 15 | beloha
# Processing Record 16 of Set 15 | raymondville
# Processing Record 17 of Set 15 | inirida
# Processing Record 18 of Set 15 | wanlaweyn
# Processing Record 19 of Set 15 | gaspe
# Processing Record 20 of Set 15 | morehead
# Processing Record 21 of Set 15 | chitipa
# Processing Record 22 of Set 15 | wheatley
# Processing Record 23 of Set 15 | le portel
# Processing Record 24 of Set 15 | is
# City not found. Skipping...
# Processing Record 25 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 15 | hoganas
# Processing Record 27 of Set 15 | necochea
# Processing Record 28 of Set 15 | kang
# Processing Record 29 of Set 15 | contai
# Processing Record 30 of Set 15 | lazaro cardenas
# Processing Record 31 of Set 15 | lodwar
# Processing Record 32 of Set 15 | yungay
# Processing Record 33 of Set 15 | high level
# Processing Record 34 of Set 15 | amapa
# Processing Record 35 of Set 15 | la macarena
# Processing Record 36 of Set 15 | jasper
# Processing Record 37 of Set 15 | veraval
# Processing Record 38 of Set 15 | waingapu
# Processing Record 39 of Set 15 | beruwala
# Processing Record 40 of Set 15 | orumiyeh
# Processing Record 41 of Set 15 | okha
# Processing Record 42 of Set 15 | crawfordsville
# Processing Record 43 of Set 15 | alta floresta
# Processing Record 44 of Set 15 | gisborne
# Processing Record 45 of Set 15 | worland
# Processing Record 46 of Set 15 | napasar
# Processing Record 47 of Set 15 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Novoseleznevo      RU  55.6821   69.2056     41.92        85          72
# 1           Dalby      AU -27.1833  151.2667     61.99        84          64
# 2     Pagsangahan      PH  13.2158  122.5431     82.78        79          86
# 3      Chokurdakh      RU  70.6333  147.9167     13.01        86          99
# 4  Guerrero Negro      MX  27.9769 -114.0611     73.29        55          86
# 5      Kautokeino      NO  69.0125   23.0412     37.87        90         100
# 6          Albany      US  42.6001  -73.9662     59.45        53         100
# 7         Mataura      NZ -46.1927  168.8643     46.35        83          99
# 8            Lebu      CL -37.6167  -73.6500     55.69        77          81
# 9       Hithadhoo      MV  -0.6000   73.0833     81.18        69          96
#
#    Wind Speed Current Description
# 0        7.29       broken clouds
# 1        1.01       broken clouds
# 2       18.70     overcast clouds
# 3       10.40     overcast clouds
# 4       10.47     overcast clouds
# 5        4.61     overcast clouds
# 6        3.00     overcast clouds
# 7        3.24     overcast clouds
# 8       13.15       broken clouds
# 9       11.59     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
